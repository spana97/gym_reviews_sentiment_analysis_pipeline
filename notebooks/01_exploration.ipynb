# %% [markdown]
# # EDA

# %% [markdown]
# - Exploring Google and Trustpilot datasets

# %%
import pandas as pd

# %%
def extract(file_path: str) -> pd.DataFrame:
    df = pd.read_csv(file_path)
    print(f"Loaded {file_path}: {df.shape[0]} rows, {df.shape[1]} columns")
    return df

# %%
google_path = '../data/raw/google_reviews.csv'
df_google = extract(google_path)
# Out:
# Loaded ../data/synthetic_data/google_reviews.csv: 1000 rows, 7 columns

# %%
df_google.head()
# Out:
#       Customer Name SurveyID for external use (e.g. tech support)  \
# 0  Stephanie Taylor          402a2e96-decd-46fd-b4ec-c4feb8d7b498
# 1      Donald Lopez          9be7aa92-938c-4973-afc0-77adfe197fc0
# 2  Gregory Humphrey          e503b9d3-fe00-4b9a-830d-399209558605
# 3    Gabriela Lewis          8993dbee-91bc-45a4-bbfb-e8c1d2b1e695
# 4       Jose Burton          8b5551ef-2bed-4689-a7b1-3f4a1d653a87
#
#       Club's Name Social Media Source Creation Date  \
# 0    Bellview Gym              Google    2023-06-23
# 1   Adamsfurt Gym              Google    2023-11-05
# 2  West Becky Gym              Google    2022-12-01
# 3   Susanview Gym              Google    2024-03-26
# 4  Lake Jerry Gym              Google    2023-08-06
#
#                                              Comment  Overall Score
# 0  Can get crowded during peak hours. Staff are v...              5
# 1  Great equipment and clean facilities. Classes ...              5
# 2  Can get crowded during peak hours. Staff are v...              3
# 3  Great equipment and clean facilities. Locker r...              2
# 4  Parking is limited but manageable. Great equip...              1

# %%
trustpilot_path = '../data/raw/trustpilot_reviews.csv'
df_trustpilot = extract(trustpilot_path)
# Out:
# Loaded ../data/synthetic_data/trustpilot_reviews.csv: 1000 rows, 15 columns

# %%
df_trustpilot.head()
# Out:
#                               Review ID Review Created (UTC)  \
# 0  f8fa662c-a210-4a15-bce1-bedfa685de34           2023-07-17
# 1  9a9d032d-a6fb-47c2-a063-14e354de15ad           2024-01-22
# 2  25a7300c-fddc-431b-8aee-ef192e0da133           2023-07-06
# 3  ace43fe9-d218-4604-9aab-ebc3197c27dd           2023-09-11
# 4  5e3cc20e-8e38-4968-ae31-5766c4c3b848           2023-06-21
#
#                 Review Consumer User ID  \
# 0  8e6b0c30-ad21-4cbe-95d2-dc9c0331ddb9
# 1  ce011074-0b08-4382-aa4a-b556986401d7
# 2  1ffcf02f-377b-4f80-875a-d7fd4f5efab8
# 3  3f840254-acca-499d-82df-d3effbe93536
# 4  21f12a1b-4eaf-4518-94ec-ed04e1c32d0b
#
#                                         Review Title  \
# 0  Atmosphere is motivating and energetic. Easy t...
# 1  Some machines were broken during my visit. Par...
# 2     Locker rooms could be cleaner. Classes are fun
# 3       Staff are very friendly and helpful. Easy to
# 4    Classes are fun and motivating. Can get crowded
#
#                                       Review Content  Review Stars  \
# 0  Atmosphere is motivating and energetic. Easy t...             1
# 1  Some machines were broken during my visit. Par...             5
# 2  Locker rooms could be cleaner. Classes are fun...             5
# 3  Staff are very friendly and helpful. Easy to b...             5
# 4  Classes are fun and motivating. Can get crowde...             1
#
#   Source Of Review Review Language                      Domain URL  \
# 0       Trustpilot              en       https://newdaniel.gym.com
# 1       Trustpilot              en  https://westaudreyfurt.gym.com
# 2       Trustpilot              en       https://smithstad.gym.com
# 3       Trustpilot              en      https://tammymouth.gym.com
# 4       Trustpilot              en       https://morsestad.gym.com
#
#           Webshop Name                      Business Unit ID  Tags  \
# 0       New Daniel Gym  15bcc111-3257-40c9-8d1f-0b85c937e99b   NaN
# 1  West Audreyfurt Gym  a30a1e35-338e-4e72-90ee-93a4b5695225   NaN
# 2        Smithstad Gym  79f3cff2-de3a-4314-bd47-cfb89b57c3ae   NaN
# 3       Tammymouth Gym  1d9f5243-2785-4199-bcb9-828ff1f83032   NaN
# 4        Morsestad Gym  f9814fce-c307-458a-ae57-98e03ed78f36   NaN
#
#    Company Reply Date (UTC)        Location Name  \
# 0                       NaN       New Daniel Gym
# 1                       NaN  West Audreyfurt Gym
# 2                       NaN        Smithstad Gym
# 3                       NaN       Tammymouth Gym
# 4                       NaN        Morsestad Gym
#
#                             Location ID
# 0  05940de5-a3f7-44e6-979d-92ccb5da6e4d
# 1  fafa0708-a6aa-4b3c-88ce-0e2e1bde96e7
# 2  87318a6d-7ee2-4039-aa59-42f622fbc00d
# 3  8941eec6-44d8-46a4-bcff-815e72ef9084
# 4  5c55ad93-7ebc-4ed6-b64c-05d1b7315fad

# %%
print(f' There are {df_google['Comment'].isnull().sum()} missing customer reviews in the Google data set')
print(f' There are {df_trustpilot['Review Content'].isnull().sum()} missing customer reviews in the Trustpilot data set')
# Out:
#  There are 0 missing customer reviews in the Google data set
#  There are 0 missing customer reviews in the Trustpilot data set

# %%
# Find the number of unique locations in the Google data set.

google_locations = set(df_google["Club's Name"])
print(f'There are {len(google_locations)} unique locations in the Google data set')
# Out:
# There are 962 unique locations in the Google data set

# %%
# Find the number of unique locations in the Trustpilot data set.

trustpilot_locations = set(df_trustpilot["Location Name"])
print(f'There are {len(trustpilot_locations)} unique locations in the Trustpilot data set')
# Out:
# There are 968 unique locations in the Trustpilot data set

# %%
# Find the number of common locations between the Google data set and the Trustpilot data set.

common_locations = set(google_locations).intersection(set(trustpilot_locations))
print(f'There are {len(common_locations)} common locations between the Google data set and the Trustpilot data set')
# Out:
# There are 57 common locations between the Google data set and the Trustpilot data set

# %%
df_google.drop_duplicates(inplace=True)
df_trustpilot.drop_duplicates(inplace=True)

df_google.dropna(subset=['Comment'], inplace=True)
df_trustpilot.dropna(subset=['Review Content'], inplace=True)

df_google.reset_index(drop=True, inplace=True)
df_trustpilot.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Visualisations

# %%
 # !pip install seaborn matplotlib wordcloud nltk
 print('Installation completed')
# Out:
# Requirement already satisfied: seaborn in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (0.13.2)
# Requirement already satisfied: matplotlib in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (3.10.8)
# Requirement already satisfied: wordcloud in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (1.9.6)
# Requirement already satisfied: nltk in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (3.9.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (from seaborn) (3.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: click in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: tqdm in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (from nltk) (4.67.3)
# Requirement already satisfied: six>=1.5 in /Users/Sean/PycharmProjects/gym_reviews_analysis/.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installation completed

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import re

import nltk
from nltk.probability import FreqDist
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag

# %%
nltk.download('all', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('omw-1.4', quiet=True)
nltk.download('averaged_perceptron_tagger_eng', quiet=True)
# Out:
# True

# %%
stop_words = set(stopwords.words('english'))
stop_word_additions = ['gym', 'club']
stop_words.update(stop_word_additions)

lemmatizer = WordNetLemmatizer()
tokenizer = word_tokenize

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^\w\s]", " ", text)
    text = re.sub(r"\d+", "", text)
    text = re.sub(r"\s+", " ", text).strip()

    return text

# %%
def tokenize_text(text):
    tokens = tokenizer(text)
    tokens = [token for token in tokens if token not in stop_words]
    return tokens

# %%
def lemmatize_tokens(tokens):
    # convert POS tag to WordNet format
    def get_wordnet_pos(word):
        tag = nltk.pos_tag([word])[0][1][0].upper()
        tag_dict = {"J": wordnet.ADJ,
                    "N": wordnet.NOUN,
                    "V": wordnet.VERB,
                    "R": wordnet.ADV}
        return tag_dict.get(tag, wordnet.NOUN)

    lemmas = [lemmatizer.lemmatize(token, get_wordnet_pos(token)) for token in tokens]

    return lemmas

# %%
def text_processing(df, column_name):
    df['clean_review'] = df[column_name].apply(clean_text)
    df['clean_review'] = df['clean_review'].apply(tokenize_text)
    df['clean_review'] = df['clean_review'].apply(lemmatize_tokens)
    return df

# %%
df_google_clean = text_processing(df_google, 'Comment')
df_google_clean.head()
# Out:
#       Customer Name SurveyID for external use (e.g. tech support)  \
# 0  Stephanie Taylor          402a2e96-decd-46fd-b4ec-c4feb8d7b498
# 1      Donald Lopez          9be7aa92-938c-4973-afc0-77adfe197fc0
# 2  Gregory Humphrey          e503b9d3-fe00-4b9a-830d-399209558605
# 3    Gabriela Lewis          8993dbee-91bc-45a4-bbfb-e8c1d2b1e695
# 4       Jose Burton          8b5551ef-2bed-4689-a7b1-3f4a1d653a87
#
#       Club's Name Social Media Source Creation Date  \
# 0    Bellview Gym              Google    2023-06-23
# 1   Adamsfurt Gym              Google    2023-11-05
# 2  West Becky Gym              Google    2022-12-01
# 3   Susanview Gym              Google    2024-03-26
# 4  Lake Jerry Gym              Google    2023-08-06
#
#                                              Comment  Overall Score  \
# 0  Can get crowded during peak hours. Staff are v...              5
# 1  Great equipment and clean facilities. Classes ...              5
# 2  Can get crowded during peak hours. Staff are v...              3
# 3  Great equipment and clean facilities. Locker r...              2
# 4  Parking is limited but manageable. Great equip...              1
#
#                                         clean_review
# 0  [get, crowd, peak, hour, staff, friendly, help...
# 1  [great, equipment, clean, facility, class, fun...
# 2  [get, crowd, peak, hour, staff, friendly, help...
# 3  [great, equipment, clean, facility, locker, ro...
# 4  [parking, limited, manageable, great, equipmen...

# %%
df_google_clean['Comment'][0]
# Out:
# 'Can get crowded during peak hours. Staff are very friendly and helpful.'

# %%
df_trustpilot_clean = text_processing(df_trustpilot, 'Review Content')
df_trustpilot_clean.head()
# Out:
#                               Review ID Review Created (UTC)  \
# 0  f8fa662c-a210-4a15-bce1-bedfa685de34           2023-07-17
# 1  9a9d032d-a6fb-47c2-a063-14e354de15ad           2024-01-22
# 2  25a7300c-fddc-431b-8aee-ef192e0da133           2023-07-06
# 3  ace43fe9-d218-4604-9aab-ebc3197c27dd           2023-09-11
# 4  5e3cc20e-8e38-4968-ae31-5766c4c3b848           2023-06-21
#
#                 Review Consumer User ID  \
# 0  8e6b0c30-ad21-4cbe-95d2-dc9c0331ddb9
# 1  ce011074-0b08-4382-aa4a-b556986401d7
# 2  1ffcf02f-377b-4f80-875a-d7fd4f5efab8
# 3  3f840254-acca-499d-82df-d3effbe93536
# 4  21f12a1b-4eaf-4518-94ec-ed04e1c32d0b
#
#                                         Review Title  \
# 0  Atmosphere is motivating and energetic. Easy t...
# 1  Some machines were broken during my visit. Par...
# 2     Locker rooms could be cleaner. Classes are fun
# 3       Staff are very friendly and helpful. Easy to
# 4    Classes are fun and motivating. Can get crowded
#
#                                       Review Content  Review Stars  \
# 0  Atmosphere is motivating and energetic. Easy t...             1
# 1  Some machines were broken during my visit. Par...             5
# 2  Locker rooms could be cleaner. Classes are fun...             5
# 3  Staff are very friendly and helpful. Easy to b...             5
# 4  Classes are fun and motivating. Can get crowde...             1
#
#   Source Of Review Review Language                      Domain URL  \
# 0       Trustpilot              en       https://newdaniel.gym.com
# 1       Trustpilot              en  https://westaudreyfurt.gym.com
# 2       Trustpilot              en       https://smithstad.gym.com
# 3       Trustpilot              en      https://tammymouth.gym.com
# 4       Trustpilot              en       https://morsestad.gym.com
#
#           Webshop Name                      Business Unit ID  Tags  \
# 0       New Daniel Gym  15bcc111-3257-40c9-8d1f-0b85c937e99b   NaN
# 1  West Audreyfurt Gym  a30a1e35-338e-4e72-90ee-93a4b5695225   NaN
# 2        Smithstad Gym  79f3cff2-de3a-4314-bd47-cfb89b57c3ae   NaN
# 3       Tammymouth Gym  1d9f5243-2785-4199-bcb9-828ff1f83032   NaN
# 4        Morsestad Gym  f9814fce-c307-458a-ae57-98e03ed78f36   NaN
#
#    Company Reply Date (UTC)        Location Name  \
# 0                       NaN       New Daniel Gym
# 1                       NaN  West Audreyfurt Gym
# 2                       NaN        Smithstad Gym
# 3                       NaN       Tammymouth Gym
# 4                       NaN        Morsestad Gym
#
#                             Location ID  \
# 0  05940de5-a3f7-44e6-979d-92ccb5da6e4d
# 1  fafa0708-a6aa-4b3c-88ce-0e2e1bde96e7
# 2  87318a6d-7ee2-4039-aa59-42f622fbc00d
# 3  8941eec6-44d8-46a4-bcff-815e72ef9084
# 4  5c55ad93-7ebc-4ed6-b64c-05d1b7315fad
#
#                                         clean_review
# 0  [atmosphere, motivate, energetic, easy, book, ...
# 1  [machine, broken, visit, parking, limited, man...
# 2  [locker, room, could, cleaner, class, fun, mot...
# 3  [staff, friendly, helpful, easy, book, class, ...
# 4     [class, fun, motivate, get, crowd, peak, hour]

# %%
def flatten_tokens(token_lists):
    return [token for sublist in token_lists for token in sublist]

# %%
def generate_wordcloud(df, column_name, title="Word Cloud"):
    all_tokens = flatten_tokens(df[column_name].dropna())
    text = " ".join(all_tokens)

    wordcloud = WordCloud(width=800, height=400, background_color='white',
                          min_font_size=10).generate(text)

    plt.figure(figsize=(10,5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(title, fontsize=16)
    plt.show()

# %%
generate_wordcloud(df_google_clean, 'clean_review', title="Google Reviews WordCloud")

# %%
generate_wordcloud(df_trustpilot_clean, 'clean_review', title="Trustpilot Reviews WordCloud")

# %%
def plot_word_frequency(df, column_name, top_n=20):
    all_tokens = flatten_tokens(df[column_name].dropna())

    fdist = FreqDist(all_tokens)
    most_common = fdist.most_common(top_n)
    words, counts = zip(*most_common)

    plt.figure(figsize=(12,6))
    plt.bar(words, counts)
    plt.xticks(rotation=45)
    plt.title(f"Top {top_n} Words Frequency")
    plt.show()

# %%
plot_word_frequency(df_google_clean, 'clean_review')

# %%
plot_word_frequency(df_trustpilot_clean, 'clean_review')

# %% [markdown]
# # Exploring negative reviews

# %%
google_rename_dict = {
    'Social Media Source': 'source',
    "Club's Name": 'location',
    'Creation Date': 'date_created',
    'Comment': 'review',
    'Overall Score': 'score',
}

# %%
trustpilot_rename_dict = {
    'Source Of Review': 'source',
    "Location Name": 'location',
    'Review Created (UTC)': 'date_created',
    'Review Content': 'review',
    'Review Stars': 'score',
}

# %%
def transform(df: pd.DataFrame, rename_dict):

    # Rename columns
    df = df.rename(columns=rename_dict)

    # Select only the renamed columns
    columns_to_keep = list(rename_dict.values())
    df = df[columns_to_keep].copy()

    # Filter on rating
    max_rating = 3
    df = df[df['score'] <= max_rating]

    return df

# %%
transformed_google = transform(df_google, google_rename_dict)

# %%
transformed_google.head()
# Out:
#    source             location date_created  \
# 2  Google       West Becky Gym   2022-12-01
# 3  Google        Susanview Gym   2024-03-26
# 4  Google       Lake Jerry Gym   2023-08-06
# 7  Google       Powellview Gym   2024-01-24
# 8  Google  West Jorgemouth Gym   2023-06-23
#
#                                               review  score
# 2  Can get crowded during peak hours. Staff are v...      3
# 3  Great equipment and clean facilities. Locker r...      2
# 4  Parking is limited but manageable. Great equip...      1
# 7  Great equipment and clean facilities. Atmosphe...      2
# 8  Staff are very friendly and helpful. Good vari...      2

# %%
transformed_trustpilot = transform(df_trustpilot, trustpilot_rename_dict)

# %%
transformed_trustpilot.head()
# Out:
#        source            location date_created  \
# 0  Trustpilot      New Daniel Gym   2023-07-17
# 4  Trustpilot       Morsestad Gym   2023-06-21
# 5  Trustpilot  Lake Adammouth Gym   2023-09-18
# 6  Trustpilot     East Angela Gym   2024-03-16
# 7  Trustpilot   Madelineville Gym   2023-07-12
#
#                                               review  score
# 0  Atmosphere is motivating and energetic. Easy t...      1
# 4  Classes are fun and motivating. Can get crowde...      1
# 5  Great equipment and clean facilities. Good var...      1
# 6  Good variety of machines and weights. Classes ...      1
# 7  Great equipment and clean facilities. Classes ...      2

# %%
print('Google:')
print(transformed_google.dtypes)
print('\nTrustpilot:')
print(transformed_trustpilot.dtypes)
# Out:
# Google:
# source            str
# location          str
# date_created      str
# review            str
# score           int64
# dtype: object
#
# Trustpilot:
# source            str
# location          str
# date_created      str
# review            str
# score           int64
# dtype: object

# %%
combined_df = pd.concat([transformed_google, transformed_trustpilot], ignore_index=True)
combined_df.head()
# Out:
#    source             location date_created  \
# 0  Google       West Becky Gym   2022-12-01
# 1  Google        Susanview Gym   2024-03-26
# 2  Google       Lake Jerry Gym   2023-08-06
# 3  Google       Powellview Gym   2024-01-24
# 4  Google  West Jorgemouth Gym   2023-06-23
#
#                                               review  score
# 0  Can get crowded during peak hours. Staff are v...      3
# 1  Great equipment and clean facilities. Locker r...      2
# 2  Parking is limited but manageable. Great equip...      1
# 3  Great equipment and clean facilities. Atmosphe...      2
# 4  Staff are very friendly and helpful. Good vari...      2

# %%
dtype_dict = {
    'source': 'string',
    'location': 'string',
    'review': 'string',
    'score': 'int64'
}

# %%
for col, dtype in dtype_dict.items():
    combined_df[col] = combined_df[col].astype(dtype)

combined_df['date_created'] = pd.to_datetime(combined_df['date_created'], errors='coerce')

# %%
combined_df_cleaned = text_processing(combined_df, 'review')
combined_df_cleaned.head()
# Out:
#    source             location date_created  \
# 0  Google       West Becky Gym   2022-12-01
# 1  Google        Susanview Gym   2024-03-26
# 2  Google       Lake Jerry Gym   2023-08-06
# 3  Google       Powellview Gym   2024-01-24
# 4  Google  West Jorgemouth Gym   2023-06-23
#
#                                               review  score  \
# 0  Can get crowded during peak hours. Staff are v...      3
# 1  Great equipment and clean facilities. Locker r...      2
# 2  Parking is limited but manageable. Great equip...      1
# 3  Great equipment and clean facilities. Atmosphe...      2
# 4  Staff are very friendly and helpful. Good vari...      2
#
#                                         clean_review
# 0  [get, crowd, peak, hour, staff, friendly, help...
# 1  [great, equipment, clean, facility, locker, ro...
# 2  [parking, limited, manageable, great, equipmen...
# 3  [great, equipment, clean, facility, atmosphere...
# 4  [staff, friendly, helpful, good, variety, mach...

# %%
generate_wordcloud(combined_df_cleaned, 'clean_review', title="Combined Reviews WordCloud")

# %%
plot_word_frequency(combined_df_cleaned, 'clean_review')

# %% [markdown]
# - The combined negative dataset could provide the business with key insights into how to improve their services for their customers through topic and sentiment analysis

# %% [markdown]
# - EDA of the real data revealed that London had the most negative reviews. A potential trial rollout of improvements at most negatively reviewed gyms would have the biggest impact.

# %% [markdown]
# - Most scores are clustered at 5 stars, so the distribution is heavily skewed. We define a low score as 3 stars or below, though with additional data and input from a domain expert, it might be more appropriate to use 2 stars or less.
